# %%
import torch

data = torch.load("/home/akshay-paliwal/Documents/VUB/thesis_ai/embeddings/embeddings/esm2/entry_00197.pt")

print(data["embedding"].shape)
print(len(data["sequence"]))
# Out:
# torch.Size([98, 1280])
# 98

# %%
import torch

data = torch.load("/home/akshay-paliwal/Documents/VUB/thesis_ai/embeddings/esm2/entry_00001.pt")

print(data["embedding"].shape)
print(len(data["sequence"]))
# Out:
# torch.Size([138, 1280])
# 138

# %%
import torch

data = torch.load("/home/akshay-paliwal/Documents/VUB/thesis_ai/embeddings/protT5/entry_00001.pt")
print(len(data["sequence"]))
# Out:
# 138
